# %%
import numpy as np

# %%
a = np.load('alignment_transformation_sim3.npy')
a
# Out:
# array([[ 0.99744419, -0.06411695, -0.03152928,  1.65731327],
#        [ 0.063672  ,  0.99785934, -0.01492058,  2.16492401],
#        [ 0.03241845,  0.01287491,  0.99939146, -1.51299172],
#        [ 0.        ,  0.        ,  0.        ,  1.        ]])

# %%
error = np.load('error_array.npy')
error
# Out:
# array([3.50214696, 3.34118404, 3.2108783 , 3.0880783 , 2.97462021,
#        2.88307143, 2.78746695, 2.70320719, 2.63673634, 2.57359806,
#        2.51178703, 2.44681602, 2.39629904, 2.35347458, 2.32139179,
#        2.35096552, 2.32022794, 2.30825499, 2.28143499, 2.27418081,
#        2.24977841, 2.22187747, 2.18401514, 2.14922063, 2.12965134,
#        2.087812  , 2.05909244, 2.0212934 , 2.00029573, 1.97312912,
#        1.95143237, 1.93270033, 1.91758481, 1.90464823, 1.87405434,
#        1.84100068, 1.8163206 , 1.80964198, 1.79327393, 1.75055075,
#        1.66758245, 1.57522551, 1.49797081, 1.43184871, 1.37642022,
#        1.3320858 , 1.28855091, 1.26930726, 1.57227448, 1.56131277,
#        1.55143541, 1.52389847, 1.4856166 , 1.4636591 , 1.47799256,
#        1.4714455 , 1.45417976, 1.43517922, 1.43772983, 1.42300875,
#        1.41827981, 1.40661202, 1.39046769, 1.36863182, 1.34503185,
#        1.33826399, 1.33107513, 1.4633169 , 1.44022043, 1.40147328,
# ...
